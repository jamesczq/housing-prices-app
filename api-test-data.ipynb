# %%
import pandas as pd

# %%
from pathlib import Path

# %%
mycsv = "data/housing.csv"

# %%
df = pd.read_csv(mycsv)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
single_sample = df.sample()
single_sample
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1143     -121.5     39.83                15.0       1896.0           408.0
#
#       population  households  median_income  median_house_value  \
# 1143       893.0       334.0         1.6948             87500.0
#
#      ocean_proximity
# 1143          INLAND

# %%
batch_samples = df.sample(10)
batch_samples
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7094     -118.00     33.91                19.0       5166.0           770.0
# 5625     -118.27     33.78                21.0       3354.0          1174.0
# 19332    -122.91     38.46                18.0       2021.0             NaN
# 3856     -118.43     34.17                33.0       1679.0           404.0
# 17214    -119.71     34.44                52.0       1837.0           343.0
# 7274     -118.24     33.98                30.0        861.0           250.0
# 5743     -118.26     34.17                20.0       5949.0          1417.0
# 13501    -117.35     34.15                32.0       2699.0           552.0
# 14743    -117.06     32.58                11.0       2879.0           679.0
# 1355     -121.92     38.03                16.0       2176.0           464.0
#
#        population  households  median_income  median_house_value  \
# 7094       2374.0       753.0         5.9790            285200.0
# ...

# %%
single_sample.to_json('data/single_test_sample.json', orient='records', lines=True)

# %%
single_sample
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1143     -121.5     39.83                15.0       1896.0           408.0
#
#       population  households  median_income  median_house_value  \
# 1143       893.0       334.0         1.6948             87500.0
#
#      ocean_proximity
# 1143          INLAND
